# %%
@max.setter
def max(self, max):
    """__maxのセッター
        Args:
            max (int): 繰り返す回数の上限
    """
    if max < 5:
        self.__max = 5 # maxが4以下なら有無を言わさず5をセット
    else:
        self.__max = max
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 @max.setter
#       2 def max(self, max):
#       3     """__maxのセッター
#       4         Args:
#       5             max (int): 繰り返す回数の上限
#       6     """
#       7     if max < 5:
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'setter'

# %%
cc = CapusuleCoach() #CapusuleCoachをインスタンス化
cc.max = 2 # countの初期値を1にする
cc.max
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cc = CapusuleCoach() #CapusuleCoachをインスタンス化
#       2 cc.max = 2 # countの初期値を1にする
#       3 cc.max
#
# NameError: name 'CapusuleCoach' is not defined
