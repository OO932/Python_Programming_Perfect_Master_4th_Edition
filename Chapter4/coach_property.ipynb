# %%
# インスタンス変数へのアクセスをプロパティ経由に書き換え
class CapsuleCoach:
    """ プロパティを実装した鬼コーチクラス
    """
    def __init__(self, max = 5, count = 0)

        """初期化メソッド
        Args:
            max (int, optional):   # 繰り返しの上限　デフォルトの値は5
            count (int, optional): # 繰り返しの回数　デフォルトの値は0

                """
