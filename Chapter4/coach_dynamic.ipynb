# %%
class DynamicCoach:
    """鬼コーチクラス
    """
    def__init__(self, max):
        """初期化メソッド
        Args:
            max(int): 繰り返しの回数
        """
    
        self.max = max
        self.count = 0

    def teach(self):
