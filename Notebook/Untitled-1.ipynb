# %%
num = 100 + 200
num
# Out:
# 300

# %%
10
# Out:
# 10

# %%
0b10
# Out:
# 2

# %%
0o10
# Out:
# 8

# %%
0x10
# Out:
# 16

# %%
'''aaa
bbb
ccc'''
# Out:
# 'aaa\nbbb\nccc'

# %%
str = '''今日の予定:
掃除
選択'''
print(str)
# Out:
# 今日の予定:
# 掃除
# 選択
