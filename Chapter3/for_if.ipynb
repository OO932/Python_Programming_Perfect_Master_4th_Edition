# %%
print('スマッシュ')
# Out:
# スマッシュ

# %%
for count in range(10): ## 処理を10回繰り返す
    print('スマッシュ' + str(count))
# Out:
# スマッシュ0
# スマッシュ1
# スマッシュ2
# スマッシュ3
# スマッシュ4
# スマッシュ5
# スマッシュ6
# スマッシュ7
# スマッシュ8
# スマッシュ9
