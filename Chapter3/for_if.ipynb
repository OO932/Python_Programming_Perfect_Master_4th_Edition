# %%
print('スマッシュ')
# Out:
# スマッシュ

# %%
for count in range(10): ## 処理を10回繰り返す
    print('スマッシュ' + str(count))
# Out:
# スマッシュ0
# スマッシュ1
# スマッシュ2
# スマッシュ3
# スマッシュ4
# スマッシュ5
# スマッシュ6
# スマッシュ7
# スマッシュ8
# スマッシュ9

# %%
for count in range(10):
    print('上' + str(count))
    print('下' + str(count))
# Out:
# 上0
# 下0
# 上1
# 下1
# 上2
# 下2
# 上3
# 下3
# 上4
# 下4
# 上5
# 下5
# 上6
# 下6
# 上7
# 下7
# 上8
# 下8
# 上9
# 下9

# %%
attack1 = 'スマッシュ'
attack2 = 'ストローク'

for count in range(10):
    if count % 2 == 0: ## countの値を2で割った余りが0であれば次のステートメントを実行
        print(attack1)
    else:              ## それ以外
        print(attack2)
# Out:
# スマッシュ
# ストローク
# スマッシュ
# ストローク
# スマッシュ
# ストローク
# スマッシュ
# ストローク
# スマッシュ
# ストローク

# %%
## スマッシュとボレーを織り交ぜた攻撃プログラムをリスト内包表記に置き換える
list = [print(attack1) if i % 2 == 0 else print(attack2) for i in range(10)]
# Out:
# スマッシュ
# ストローク
# スマッシュ
# ストローク
# スマッシュ
# ストローク
# スマッシュ
# ストローク
# スマッシュ
# ストローク

# %%
attack1 = 'ボレー'
attack2 = 'スマッシュ'
attack3 = 'ストローク'
 
for count in range(10):
    if (6 <= count) and (count % 2 == 0): ## countが6以上､かつ2で割った余りが0であるか?
        print(attack1)
    elif (count % 2 == 0):               ## countを2で割った余りが0であるか?
        print(attack2)
    else:                               ## どれにも当てはまらない場合に実行
        print(attack3)
# Out:
# スマッシュ
# ストローク
# スマッシュ
# ストローク
# スマッシュ
# ストローク
# ボレー
# ストローク
# ボレー
# ストローク
