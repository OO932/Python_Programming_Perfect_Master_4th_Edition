# %%
attacks = ['グランドストローク', 'ボレー', 'スマッシュ', 'ロブ']
for count in range(5):
    for attack in attacks:
        print(attack,' ', end='')
    print()
# Out:
# グランドストローク  ボレー  スマッシュ  ロブ
# グランドストローク  ボレー  スマッシュ  ロブ
# グランドストローク  ボレー  スマッシュ  ロブ
# グランドストローク  ボレー  スマッシュ  ロブ
# グランドストローク  ボレー  スマッシュ  ロブ

# %%
attacks = ['グランドストローク', 'ボレー', 'スマッシュ', 'ロブ']
attacks[0]
attacks[1]
attacks[2]
attacks[3]
# Out:
# 'ロブ'

# %%
## ネガティブインデックスでアクセス
attacks = ['グランドストローク', 'ボレー', 'スマッシュ', 'ロブ']
attacks[-1] ## 最後の要素にアクセス
attacks[-2]
attacks[-3]
attacks[-4]
# Out:
# 'グランドストローク'
